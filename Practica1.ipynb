# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit

# %%
df = pd.read_csv('https://raw.githubusercontent.com/SantiagoJulioD/Personal/refs/heads/main/datosp1.csv')

# %%
V1 = df.V1.values
V2 = df.V2.values

# %%
df
# Out:
#          V1     V2
# 0     264.0  114.0
# 1     239.0  119.0
# 2     240.0  107.0
# 3     231.0  150.0
# 4     241.0  130.0
# ..      ...    ...
# 251  4095.0  606.0
# 252  4095.0  591.0
# 253  4095.0  617.0
# 254  4095.0  636.0
# 255  4095.0  637.0
#
# [256 rows x 2 columns]

# %%
Vd = V2*3./4095
Id = (V1 - V2)*3./4095*1000

# %%
func = lambda x,a,b,c: a*np.exp(b*x)+c

# %%
params,_ = curve_fit(func,Vd,Id)

# %%
plt.plot(Vd,Id)
plt.plot(Vd,func(Vd,*params))
